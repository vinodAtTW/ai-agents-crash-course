# %%
from typing import Dict, List

import chromadb
import pandas as pd


def prepare_nutrition_documents(csv_path: str) -> Dict:
    """
    Convert nutrition CSV into ChromaDB-ready documents.
    Each food item becomes a searchable document.
    """
    df = pd.read_csv(csv_path)

    documents = []
    metadatas = []
    ids = []

    for index, row in df.iterrows():
        # Create rich document text for semantic search
        row["Cals_per100grams"] = row["Cals_per100grams"].replace(" cal", "")
        row["KJ_per100grams"] = row["KJ_per100grams"].replace(" kJ", "")
        document_text = f"""
        Food: {row['FoodItem']}
        Category: {row['FoodCategory']}
        Nutritional Information:
        - Calories: {row['Cals_per100grams']} per 100g
        - Energy: {row['KJ_per100grams']} kJ per 100g
        - Serving size reference: {row['per100grams']}

        This is a {row['FoodCategory'].lower()} food item that provides {row['Cals_per100grams']} calories per 100 grams.
        """.strip()

        # Rich metadata for filtering and exact lookups
        metadata = {
            "food_item": row["FoodItem"].lower(),
            "food_category": row["FoodCategory"].lower(),
            "calories_per_100g": (
                float(row["Cals_per100grams"])
                if pd.notna(row["Cals_per100grams"])
                else 0
            ),
            "kj_per_100g": (
                float(row["KJ_per100grams"]) if pd.notna(row["KJ_per100grams"]) else 0
            ),
            "serving_info": row["per100grams"],
            # Add searchable keywords
            "keywords": f"{row['FoodItem'].lower()} {row['FoodCategory'].lower()}".replace(
                " ", "_"
            ),
        }

        documents.append(document_text)
        metadatas.append(metadata)
        ids.append(f"food_{index}")

    return {"documents": documents, "metadatas": metadatas, "ids": ids}


def setup_nutrition_chromadb(csv_path: str, collection_name: str = "nutrition_db"):
    """
    Create and populate ChromaDB collection with nutrition data.
    """
    # Initialize ChromaDB
    client = chromadb.PersistentClient("../chroma")

    # Create collection (delete if exists)
    try:
        client.delete_collection(collection_name)
    except BaseException:
        pass

    collection = client.create_collection(
        name=collection_name,
        metadata={
            "description": "Nutrition database with calorie and food information"
        },
    )

    # Prepare documents
    data = prepare_nutrition_documents(csv_path)

    # Add to ChromaDB
    collection.add(
        documents=data["documents"], metadatas=data["metadatas"], ids=data["ids"]
    )

    print(
        f"Added {len(data['documents'])} food items to ChromaDB collection '{collection_name}'"
    )
    return collection

# %%
collection = setup_nutrition_chromadb("data/calories.csv", nutrition_db)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 collection = setup_nutrition_chromadb("data/calories.csv", nutrition_db)
#
# Cell In[1], line 72, in setup_nutrition_chromadb(csv_path, collection_name)
#      69 except BaseException:
#      70     pass
# ---> 72 collection = client.create_collection(
#      73     name=collection_name,
#      74     metadata={
#      75         "description": "Nutrition database with calorie and food information"
#      76     },
#      77 )
#      79 # Prepare documents
#      80 data = prepare_nutrition_documents(csv_path)
#
# File ~/.local/lib/python3.13/site-packages/chromadb/api/client.py:177, in Client.create_collection(self, name, configuration, metadata, embedding_function, data_loader, get_or_create)
#     174 if embedding_function is not None and configuration_ef is None:
#     175     configuration["embedding_function"] = embedding_function
# --> 177 model = self._server.create_collection(
#     178     name=name,
#     179     metadata=metadata,
#     180     tenant=self.tenant,
#     181     database=self.database,
#     182     get_or_create=get_or_create,
#     183     configuration=configuration,
#     184 )
#     185 return Collection(
#     186     client=self._server,
#     187     model=model,
#     188     embedding_function=embedding_function,
#     189     data_loader=data_loader,
#     190 )
#
# File ~/.local/lib/python3.13/site-packages/chromadb/api/rust.py:229, in RustBindingsAPI.create_collection(self, name, configuration, metadata, get_or_create, tenant, database)
#     226 else:
#     227     configuration_json_str = None
# --> 229 collection = self.bindings.create_collection(
#     230     name, configuration_json_str, metadata, get_or_create, tenant, database
#     231 )
#     232 collection_model = CollectionModel(
#     233     id=collection.id,
#     234     name=collection.name,
#    (...)    239     database=collection.database,
#     240 )
#     241 return collection_model
#
# TypeError: argument 'name': 'Collection' object cannot be converted to 'PyString'

# %%
chroma_client = chromadb.PersistentClient(path="../chroma")
nutrition_db = chroma_client.get_collection(name="nutrition_db")

results = nutrition_db.query(query_texts=["banana"], n_results=3)
for i, doc in enumerate(results["documents"][0]):
    print(results["metadatas"][0][i])
    print(doc)
    print("\n")
# Out:
# /home/vscode/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:07<00:00, 10.9MiB/s]
# {'food_category': 'fruits', 'serving_info': '100g', 'keywords': 'banana_fruits', 'calories_per_100g': 89.0, 'kj_per_100g': 374.0, 'food_item': 'banana'}
# Food: Banana
#         Category: Fruits
#         Nutritional Information:
#         - Calories: 89 per 100g
#         - Energy: 374 kJ per 100g
#         - Serving size reference: 100g
#
#         This is a fruits food item that provides 89 calories per 100 grams.
#
#
# {'serving_info': '100ml', 'food_item': 'banana juice', 'calories_per_100g': 50.0, 'keywords': 'banana_juice_(fruit)juices', 'kj_per_100g': 210.0, 'food_category': '(fruit)juices'}
# Food: Banana Juice
#         Category: (Fruit)Juices
#         Nutritional Information:
#         - Calories: 50 per 100g
#         - Energy: 210 kJ per 100g
#         - Serving size reference: 100ml
#
#         This is a (fruit)juices food item that provides 50 calories per 100 grams.
#
#
# {'food_item': 'banana', 'food_category': 'tropical&exoticfruits', 'keywords': 'banana_tropical&exoticfruits', 'serving_info': '100g', 'kj_per_100g': 374.0, 'calories_per_100g': 89.0}
# Food: Banana
#         Category: Tropical&ExoticFruits
#         Nutritional Information:
#         - Calories: 89 per 100g
#         - Energy: 374 kJ per 100g
#         - Serving size reference: 100g
#
#         This is a tropical&exoticfruits food item that provides 89 calories per 100 grams.
